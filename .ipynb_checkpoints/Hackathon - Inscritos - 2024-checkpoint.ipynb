# %%
import numpy as np
import pandas as pd
import math 
import regex as re
from datetime import datetime
import timedelta as td
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def dirImagens(pDirImagem):
    try:
        if (not os.path.isdir(pDirImagem)):
            os.mkdir(pDirImagem)
    except OSError as e:
        print(e.args[1])
    
def abriPlanilha():
    diretorio='./data/'
    for arquivo in os.listdir(diretorio):
        if (re.findall('csv', arquivo)):
            return (diretorio+arquivo)
    
dirImagens('Imagens')
    
ins = pd.read_csv(abriPlanilha()
                 ,header=1
                 ,sep=','
                 ,low_memory=True
                 )

# %%
colunas=['col1','col2','col3','situacao','nroInscricao','nome',
        'cpf','dataNascimento','genero','escolaridade',
        'instituicao','telefone','email','cep','bairro',
        'cidade','incluiOutro','perfil','observacao','perfis']

ins.columns=colunas

# %%
def columnsDrop():
    ins.drop('situacao', axis=1, inplace=True)
    ins.dropna(axis=1, how='all', inplace=True)
    ins.dropna(axis=0, how='all', inplace=True)

columnsDrop()

# %%
def columnsInsert():
    ins.insert(3, 'cpfAjustado', '')
    ins.insert(5, 'idade', 0)
    ins.insert(6, 'dataNascAjustada', ' ')
    ins.insert(8, 'generoId', 99)
    ins.insert(10, 'escolaridadeId', 0)
    ins.insert(11, 'escolaridade2', ' ')
    ins.insert(13, 'instituicaoId', 0)
    ins.insert(15, 'telefoneAjustado', '')
    ins.insert(18, 'cepAjustado', '')
    ins.insert(21, 'cidadeId', 0)
    ins.insert(25, 'tamanhoCamisetaId', 0)

columnsInsert()

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57 entries, 0 to 56
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nroInscricao       57 non-null     object
#  1   nome               57 non-null     object
#  2   cpf                57 non-null     object
#  3   cpfAjustado        57 non-null     object
#  4   dataNascimento     57 non-null     object
#  5   idade              57 non-null     int64
#  6   dataNascAjustada   57 non-null     object
#  7   genero             57 non-null     object
#  8   generoId           57 non-null     int64
#  9   escolaridade       57 non-null     object
#  10  escolaridadeId     57 non-null     int64
#  11  escolaridade2      57 non-null     object
#  12  instituicao        49 non-null     object
#  13  instituicaoId      57 non-null     int64
#  14  telefone           56 non-null     object
#  15  telefoneAjustado   57 non-null     object
#  16  email              57 non-null     object
#  17  cep                57 non-null     object
#  18  cepAjustado        57 non-null     object
#  19  bairro             57 non-null     object
#  20  cidade             57 non-null     object
#  21  cidadeId           57 non-null     int64
#  22  incluiOutro        57 non-null     object
#  23  perfil             57 non-null     object
#  24  observacao         57 non-null     object
#  25  tamanhoCamisetaId  57 non-null     int64
# dtypes: int64(6), object(20)
# memory usage: 12.0+ KB

# %%
ins.head(3)
# Out:
#   nroInscricao                                nome          cpf cpfAjustado  \
# 0            1  Isabelle Victoria Pereira De Souza  51454217880
# 1            2         Guilherme Antunes de Campos  50069148821
# 2            3     Wezilyana Melice Farias de Lima   1264343442
#
#   dataNascimento  idade dataNascAjustada     genero  generoId  \
# 0     12/09/2003      0                    Feminino        99
# 1     03/06/2004      0                   Masculino        99
# 2     13/08/1983      0                    Feminino        99
#
#                escolaridade  ...                           email        cep  \
# 0           Ensino Superior  ...  isabellevictoria.urs@gmail.com  08121-620
# 1  Ensino Superior Cursando  ...              guiancam@gmail.com    7091000
# 2    Pós-graduação completo  ...            lilyfarias@gmail.com    1529001
#
#   cepAjustado          bairro     cidade cidadeId incluiOutro  \
# 0                    Jd Nélia  São Paulo        0           N
# 1              Vila Progresso  Guarulhos        0           N
# 2                   Aclimação  São Paulo        0           N
#
#                  perfil              observacao tamanhoCamisetaId
# 0         Desenvolvedor  Tamanho de Camiseta: M                 0
# 1         Desenvolvedor  Tamanho de Camiseta: G                 0
# 2  Analista de Negócios  Tamanho de Camiseta: M                 0
#
# [3 rows x 26 columns]

# %%
def cpfAjustado(cpf) -> str:
    pattern='([0-9]{3})([.])([0-9]{3})([.])([0-9]{3})([-])([0-9]{2})'
    if (re.search(pattern, cpf)):
        return cpf
    
    cpf=re.sub('[\.\-]','',cpf); cpf=cpf.zfill(11)
        
    pattern='([0-9]{3})([0-9]{3})([0-9]{3})([0-9]{2})'
    cpf=re.search(pattern, cpf)
    cpf='{}.{}.{}-{}'.format(cpf.group(1)
                            ,cpf.group(2)
                            ,cpf.group(3)
                            ,cpf.group(4)
                            )
    return cpf

def dataNascAjustada(pDataNascimento : str, éIdade : bool = False):
    dtNasc=pDataNascimento; dtRef=''
    #   
    pattern='([0-9]{1,2})([/])([0-9]{1,2})([/])([0-9]{2,4})'
        
    if (not re.search(pattern, dtNasc)):
        if (len(dtNasc)==6 or len(dtNasc)==8):
            pattern='([0-9]{2})([0-9]{2})([0-9]{2,4})'
            dtNasc=re.search(pattern, dtNasc)
            if (dtNasc):
                dtNasc='{}/{}/{}'.format(dtNasc.group(1),
                                        dtNasc.group(2),
                                        dtNasc.group(3)
                                        )
            else:
                return -1
            
        else:
            return -1
        
    dtNasc=datetime.strptime(dtNasc, '%d/%m/%Y')
                
    if (éIdade):
        diferencaData=(datetime.today()-dtNasc)
        dias=diferencaData.days
        anos, dias = divmod(dias, 365)
        dtRef=anos
    else:
        dtRef=dtNasc.strftime('%d/%m/%Y %H:%M:%S')
    
    return dtRef

def quantGenero(genero) -> int:
    if (genero.upper()=='FEMININO'):
        return 1
    elif (genero.upper()=='MASCULINO'):
        return 2
    else:
        return 99
    
def quantEscolaridade(escolaridade) -> int:
    escolaridade=escolaridade.upper()
    valor=0
    if re.findall('M[EÉ]DIO', escolaridade):
        valor=10
    elif (re.findall('SUPERIOR', escolaridade) or
         re.findall('FACULDADE', escolaridade)):
        valor=20
    elif re.findall('P[ÓO]S', escolaridade):
        valor=30
    elif re.findall('MESTRADO', escolaridade):
        valor=40
    elif re.findall('DOUTORADO', escolaridade):
        valor=50
    else:
        return valor
          
    if (not (re.findall('INCOMPLETO', escolaridade) or 
        re.findall('CURSANDO', escolaridade))):
        valor+=5
        
    return valor

def qualEscolaridade(escolaridade) -> str:
    escolaridade=escolaridade.upper()
    texto='N/D'
    if re.findall('M[EÉ]DIO', escolaridade):
        texto='ENS.MÉDIO'
    elif (re.findall('SUPERIOR', escolaridade) or
         re.findall('FACULDADE', escolaridade) or
         re.findall('BACHAREL', escolaridade)
         ):
        texto='ENS.SUPERIOR'
    elif re.findall('P[ÓO]S', escolaridade):
        texto='PÓS-GRADUAÇÃO'
    elif re.findall('MESTRADO', escolaridade):
        texto='MESTRADO'
    elif re.findall('DOUTORADO', escolaridade):
        texto='DOUTORADO'
    else:
        return texto
          
    if (not (re.findall('INCOMPLETO', escolaridade) or 
        re.findall('CURSANDO', escolaridade) or
        re.findall('ANDAMENTO', escolaridade))):
        texto=texto+' COMPLETO'
    else:
        texto=texto+' INCOMPLETO/CURSANDO'
        
    return texto

def telefoneAjustado(fone) -> str:
    #print('Telefone: {}'.format(fone))

    if (pd.isnull(fone)):
        #print('Não informado!'); print('----------------')
        return 'Não informado!'
    
    pattern='([\(])([0-9]{2})([\)])([\ ])([0-9]{5})([-])([0-9]{4})'
    if (re.search(pattern, fone)):
        #print('foneCond.1: '+fone); print('----------------')
        return fone

    for char in ([' ','-','\(','\)']):
        fone=re.sub(char,'',fone)
    
    pattern='([0-9]{2})([0-9]{5})([0-9]{4})'
    if (re.search(pattern, fone) and (not re.search('^55', fone))): 
        fone=re.search(pattern, fone)
        fone='({}) {}-{}'.format(fone.group(1)
                                 ,fone.group(2)
                                 ,fone.group(3)
                                )
        #print('foneCond.2: '+fone); print('----------------')
    elif (re.search('^55',fone)):
        pattern = '([0-9]{2})([0-9]{2})([0-9]{5})([0-9]{4})'
        fone=re.search(pattern, fone)
        fone='({}) {}-{}'.format(
                                fone.group(2)
                                ,fone.group(3)
                                ,fone.group(4)
                                )
        #print('foneCond.3: '+fone); print('----------------')
    else:
        #print('Inválido'); print('----------------')
        fone='Inválido'

    return fone

def quantInstituicao(pInstituicao) -> int:
    tp=type(pInstituicao)
    if (tp==str):
        pInst=pInstituicao.upper()
        
        if (re.findall('BELAS ARTES', pInst)):
            return 1
        elif (re.findall('FATEC', pInst)):
            return 2
        elif (re.findall('WYDEN', pInst)):
            return 3
        elif (re.findall('JUDAS', pInst)):
            return 4
        elif (re.findall('IFSP', pInst) or re.findall('INSTITUTO FEDERAL', pInst)):
            return 5
        elif (re.findall('ENIAC', pInst)):
            return 6
        elif (re.findall('FIAP', pInst)):
            return 7
        elif (re.findall('FAM', pInst)):
            return 8
        elif (re.findall('UNICAMP', pInst)):
            return 9
        elif (re.findall('ETEC', pInst)):
            return 10
        elif (re.findall('LICEU', pInst)):
            return 11
        elif (re.findall('MOACYR CAMPOS', pInst)):
            return 12
        elif (re.findall('USP', pInst) or re.findall('UNIVERSIDADE DE S[AÃ]O PAULO', pInst)):
            return 13
        elif (re.findall('DRUMMOND', pInst)):
            return 14
        elif (re.findall('IMPACTA', pInst)):
            return 15
        elif (re.findall('VUNESP', pInst)):
            return 16
        elif (re.findall('SAL[EÉ]M', pInst)):
            return 17
        elif (re.findall('TORRICELLI', pInst)):
            return 18
        else:
            return 99
      
    elif (tp==float):
        return 0

    return 99

def cepAjustado(cep) -> str:
    pattern='([0-9]{5})([-]{1})([0-9]{3})'
    if (not re.search(pattern, cep)):
        cep=re.sub('-','', cep)
        cep=cep.zfill(8)
        pattern='([0-9]{5})([0-9]{3})'
        cep=re.search(pattern, cep)
        cep='{}-{}'.format(cep.group(1),cep.group(2))
    return cep

def cidadeMaiuscula(cidade) -> str:
    return str.upper(cidade)

def quantCidade(cidade) -> int:
    cidade=cidade.upper()
    if re.findall('GUARULHOS', cidade):
        return 1
    elif re.findall('S[ÃA]O PAULO', cidade):
        return 2
    elif re.findall('RIBEIR[ÃA]O PRETO', cidade):
        return 3
    elif re.findall('SANTO ANDR[ÉE]', cidade):
        return 4
    elif re.findall('GUARUJ[ÁA]', cidade):
        return 5
    elif re.findall('IGARAT[ÁA]', cidade):
        return 6
    elif re.findall('CARAPICU[ÍI]BA', cidade):
        return 7
    elif re.findall('S[ÃA]O VICENTE', cidade):
        return 8
    else:
        return 99

def quantTamanhoCamiseta(pTamanho) -> int:
    t=re.split('\s',pTamanho)
    if (t[len(t)-1]=='P'):
        return 1
    elif (t[len(t)-1]=='M'):
        return 2
    elif (t[len(t)-1]=='G'):
        return 3
    elif (t[len(t)-1]=='GG'):
        return 4
    else:
        return 99

# %%
ins['cpfAjustado']=ins['cpf'].apply(lambda cpf: cpfAjustado(cpf))
ins['idade']=ins['dataNascimento'].apply(lambda dtNasc: dataNascAjustada(dtNasc, True))
ins['dataNascAjustada']=ins['dataNascimento'].apply(lambda dtNasc: dataNascAjustada(dtNasc, False))
ins['generoId']=ins['genero'].apply(lambda genero: quantGenero(genero))
ins['escolaridadeId']=ins['escolaridade'].apply(lambda escolaridade: quantEscolaridade(escolaridade))
ins['escolaridade2']=ins['escolaridade'].apply(lambda escolaridade: qualEscolaridade(escolaridade))
ins['instituicaoId']=ins['instituicao'].apply(lambda instituicao: quantInstituicao(instituicao))
ins['telefoneAjustado']=ins['telefone'].apply(lambda fone: telefoneAjustado(fone))
ins['cepAjustado']=ins['cep'].apply(lambda cep : cepAjustado(cep))
ins['cidade']=ins['cidade'].apply(lambda cidade : cidadeMaiuscula(cidade))
ins['cidadeId']=ins['cidade'].apply(lambda cidade: quantCidade(cidade))
ins['tamanhoCamisetaId']=ins['observacao'].apply(lambda obs: quantTamanhoCamiseta(obs))

# %%
ins
# Out:
#                nroInscricao                                nome  \
# 0                         1  Isabelle Victoria Pereira De Souza
# 1                         2         Guilherme Antunes de Campos
# 2                         3     Wezilyana Melice Farias de Lima
# 3                         4                 Jéssica Bueno Ramos
# 4                         5      Gabriel Vinícius Rocha Barboza
# 5                         6              Richard Klaoss Neumann
# 6                         7          Cristofer Batista da Silva
# 7                         8               Thiago Henrique Silva
# 8                         9            Anaíle Silva de Oliveira
# 9                        10             Leonardo dos Reis Souza
# 10                       11    Maria Santiellas Costa Rodrigues
# 11                     12.1               Andrey Oliveira Pinto
# 12                     12.2         Giovanna Carvalho de Moraes
# 13                     12.3           Sthefany dos Santo Soares
# 14                     12.4            Laura Carvalho de Moraes
# 15                       13          Thaiza Carvalho Nascimento
# 16                       14     Esther Felipe dos Santos Farias
# 17                       15                   Cristhian Ruescas
# 18                       16           Uara sales alves de sousa
# 19                       17               Felipe Vinícius Pedro
# 20                       18             Lucas da Silva Nicoleti
# 21                     19.1                 Murillo Nunes Baima
# 22                     19.2                 Enzo de Melo Galvão
# 23                       20                        Jairo Mendes
# 24                     21.1            Caroline Alves Florencio
# 25                     21.2  Rafael Gustavo de Oliveira Pereira
# 26                     22.1             Bruna de Almeida Pessoa
# 27                     22.2           Leticia Ferreira da Silva
# 28                     22.3         Miguel do Nascimento Vieira
# 29                     22.4             Sandra Rojas Zegarrundo
# 30                       23           Guilherme Pereira Martins
# 31  24/25 ERRO DE INSCRIÇÃO           Joao Rubens Belluzzo Neto
# 32                       26                 Ayke de Souza Lopes
# 33                       27         Eduardo Almeida de Oliveira
# 34                       28                    Kauã De Oliveira
# 35                       29          DAIANE NEVES DO NASCIMENTO
# 36                     30.1                    Fernando Mariano
# 37                     30.2           Júlia Almeida de Oliveira
# 38                     31.1     Luara Martins de Oliveira Ramos
# 39                     31.2                 Mônica Inês Martins
# 40                     32.1                  Daniel Xavier Rios
# 41                     32.2                   Luiza Mell Rufino
# 42                     32.3         Julia Petra Teixeira Chaves
# 43                     32.4             Manuela Moreira Gadelho
# 44                       33              Thiago Oliveira Caldas
# 45                       34                 Ana Beatriz Mamprin
# 46                     35.1         Luís Eduardo Cassiano silva
# 47                     35.2                 Ana Beatriz mamprin
# 48                       36                Giane Mayumi Galhard
# 49                       37          Flavia Firmino de Oliveira
# 50                       38        JEFFERSON ALVES CORREIA LIMA
# 51                       39          Thaiza Carvalho Nascimento
# 52                       40         Renato Gonçalves dos Santos
# 53                     41.1                Sabrina Lopes Soares
# 54                     41.2            Jhordan dos Santos Alves
# 55                       42              Paulo Roberto da Silva
# 56                       43                Milena Barbosa Prado
#
#                cpf     cpfAjustado dataNascimento  idade     dataNascAjustada  \
# 0      51454217880  514.542.178-80     12/09/2003     20  12/09/2003 00:00:00
# 1      50069148821  500.691.488-21     03/06/2004     19  03/06/2004 00:00:00
# 2       1264343442  012.643.434-42     13/08/1983     40  13/08/1983 00:00:00
# 3      51713271818  517.132.718-18     11/01/2005     19  11/01/2005 00:00:00
# 4      46993988801  469.939.888-01     17/01/2005     19  17/01/2005 00:00:00
# 5      54807928813  548.079.288-13     30/07/2005     18  30/07/2005 00:00:00
# 6      48859050871  488.590.508-71     14/02/2005     19  14/02/2005 00:00:00
# 7      38298390814  382.983.908-14     22/06/2002     21  22/06/2002 00:00:00
# 8      23033966896  230.339.668-96     19/02/2002     22  19/02/2002 00:00:00
# 9      53872905880  538.729.058-80     23/09/2003     20  23/09/2003 00:00:00
# 10     35403699880  354.036.998-80     29/11/1988     35  29/11/1988 00:00:00
# 11     56851805863  568.518.058-63     03/03/2005     18  03/03/2005 00:00:00
# 12     50546847862  505.468.478-62     16/04/2006     17  16/04/2006 00:00:00
# 13     57520934810  575.209.348-10     30/05/2004     19  30/05/2004 00:00:00
# 14     50288218876  502.882.188-76     28/04/2008     15  28/04/2008 00:00:00
# 15     45016234892  450.162.348-92     02/10/2002     21  02/10/2002 00:00:00
# 16     46238473819  462.384.738-19     27/02/2003     21  27/02/2003 00:00:00
# 17     46894337802  468.943.378-02     29/07/2003     20  29/07/2003 00:00:00
# 18     40974681890  409.746.818-90     09/02/2004     20  09/02/2004 00:00:00
# 19     46304752814  463.047.528-14     22/08/1996     27  22/08/1996 00:00:00
# 20     39969447807  399.694.478-07     27/11/1996     27  27/11/1996 00:00:00
# 21     39387885852  393.878.858-52      9/10/2006     17  09/10/2006 00:00:00
# 22     45380227805  453.802.278-05     28/05/2006     17  28/05/2006 00:00:00
# 23     35146549800  351.465.498-00     12/10/1984     39  12/10/1984 00:00:00
# 24  520.096.608-62  520.096.608-62     31/12/2002     21  31/12/2002 00:00:00
# 25     49533400862  495.334.008-62     21/09/1998     25  21/09/1998 00:00:00
# 26     36965492821  369.654.928-21     27/02/1998     26  27/02/1998 00:00:00
# 27     45712576864  457.125.768-64     05/03/2004     19  05/03/2004 00:00:00
# 28  064.796.301-90  064.796.301-90     20/09/2001     22  20/09/2001 00:00:00
# 29     37580996847  375.809.968-47     05/11/1989     34  05/11/1989 00:00:00
# 30      5698607810  056.986.078-10       20072005     18  20/07/2005 00:00:00
# 31     54562250852  545.622.508-52        5082001     -1                   -1
# 32     52489918893  524.899.188-93     31/01/2005     19  31/01/2005 00:00:00
# 33  301.583.998-54  301.583.998-54     14/01/1982     42  14/01/1982 00:00:00
# 34     55983509802  559.835.098-02      27/2/2004     20  27/02/2004 00:00:00
# 35     34002486818  340.024.868-18     30/01/1986     38  30/01/1986 00:00:00
# 36     23207189822  232.071.898-22       28021998     26  28/02/1998 00:00:00
# 37     52636726867  526.367.268-67     06/05/2007     16  06/05/2007 00:00:00
# 38     44579251873  445.792.518-73     18/08/2024     -1  18/08/2024 00:00:00
# 39    009375828-67  009.375.828-67     11/11/1960     63  11/11/1960 00:00:00
# 40     37202114879  372.021.148-79      14/2/2003     21  14/02/2003 00:00:00
# 41     59575799801  595.757.998-01     03/10/2007     16  03/10/2007 00:00:00
# 42     50301354804  503.013.548-04     09/04/2001     22  09/04/2001 00:00:00
# 43     52184260835  521.842.608-35     14/08/2002     21  14/08/2002 00:00:00
# 44  547.572.318-84  547.572.318-84     25/12/2005     18  25/12/2005 00:00:00
# 45     48524828889  485.248.288-89     06/04/1998     25  06/04/1998 00:00:00
# 46     43901984836  439.019.848-36     18/05/1998     25  18/05/1998 00:00:00
# 47     48524828889  485.248.288-89     06/04/1998     25  06/04/1998 00:00:00
# 48     49149278886  491.492.788-86     09/11/2003     20  09/11/2003 00:00:00
# 49     41125303824  411.253.038-24       29031993     30  29/03/1993 00:00:00
# 50     35603359811  356.033.598-11      16/3/1986     37  16/03/1986 00:00:00
# 51     45016234892  450.162.348-92     02/10/2002     21  02/10/2002 00:00:00
# 52     38751297841  387.512.978-41       14071990     33  14/07/1990 00:00:00
# 53     53671050845  536.710.508-45      21/9/2003     20  21/09/2003 00:00:00
# 54     46545118811  465.451.188-11       1/9/1999     24  01/09/1999 00:00:00
# 55  435.130.438-30  435.130.438-30     26/02/1997     27  26/02/1997 00:00:00
# 56     46771242803  467.712.428-03       27121997     26  27/12/1997 00:00:00
#
#          genero  generoId                                       escolaridade  \
# 0      Feminino         1                                    Ensino Superior
# 1     Masculino         2                           Ensino Superior Cursando
# 2      Feminino         1                             Pós-graduação completo
# 3      Feminino         1                           Ensino Superior Cursando
# 4     Masculino         2  Cursando Ensino Superior em Análise e desenvol...
# 5     Masculino         2                    Ensino médio e técnico completo
# 6     Masculino         2                              Ensino Médio Completo
# 7     Masculino         2                         Ensino Superior Incompleto
# 8      Feminino         1                         Ensino Superior Incompleto
# 9     Masculino         2                                  Cursando superior
# 10     Feminino         1                             Pós graduação completa
# 11    Masculino         2                              Ensino Médio completo
# 12     Feminino         1                              Ensino Médio completo
# 13     Feminino         1                              Ensino Médio completo
# 14     Feminino         1                            Ensino Médio incompleto
# 15     Feminino         1                                  Superior cursando
# 16     Feminino         1                      6º Período - Engenharia Civil
# 17    Masculino         2                                 Cursando Faculdade
# 18     Feminino         1                                Superior incompleto
# 19    Masculino         2                                           Superior
# 20    Masculino         2                           Pós-graduação incompleto
# 21    Masculino         2                            Ensino médio incompleto
# 22    Masculino         2                            ENSINO MEDIO INCOMPLETO
# 23    Masculino         2                                Superior Incompleto
# 24     Feminino         1     Cursando Analise e Desenvolvimento de Sistemas
# 25    Masculino         2                                       Ensino medio
# 26     Feminino         1                                Superior (cursando)
# 27     Feminino         1                                Superior (cursando)
# 28    Masculino         2                         Ensino superior incompleto
# 29     Feminino         1                                           Superior
# 30    Masculino         2                              Ensino Médio Completo
# 31    Masculino         2                           Cursando Ensino Superior
# 32    Masculino         2                         ensino superior incompleto
# 33    Masculino         2                                  Superior completo
# 34    Masculino         2                              Ensino Médio Completo
# 35     Feminino         1                                           Bacharel
# 36    Masculino         2                              Ensino médio completo
# 37     Feminino         1                                              Júlia
# 38     Feminino         1                Ensino Médio Completo com Tecnólogo
# 39     Feminino         1                               Graduação Jornalismo
# 40    Masculino         2  Cursando Graduação em Análise e Desenvolviment...
# 41     Feminino         1                            Cursando o Ensino Médio
# 42     Feminino         1  Cursando Graduação em Análise e Desenvolviment...
# 43     Feminino         1  Cursando Graduação em Análise e Desenvolviment...
# 44    Masculino         2               Ensino médio - (Último ano em curso)
# 45     Feminino         1                                Superior Incompleto
# 46    Masculino         2                                  Cursando superior
# 47     Feminino         1                                  Cursando superior
# 48     Feminino         1                       Ensino Superior em andamento
# 49     Feminino         1                                           Graduada
# 50  NÃO BINARIO        99                                    ENSINO SUPERIOR
# 51     Feminino         1                                  Superior Cursando
# 52    Masculino         2                              Graduação tecnológica
# 53     Feminino         1                                    Ensino Superior
# 54    Masculino         2                                       Ensino Médio
# 55    Masculino         2                                  Superior completo
# 56     Feminino         1                                  Superior completo
#
#     ...                              email          cep cepAjustado  \
# 0   ...     isabellevictoria.urs@gmail.com    08121-620   08121-620
# 1   ...                 guiancam@gmail.com      7091000   07091-000
# 2   ...               lilyfarias@gmail.com      1529001   01529-001
# 3   ...       jessicabuenoramos5@gmail.com      7141420   07141-420
# 4   ...      gabrielrochabarboza@gmail.com    07135-720   07135-720
# 5   ...     richardklaossneumann@gmail.com      7230450   07230-450
# 6   ...        cristofersilva.rp@gmail.com     14050220   14050-220
# 7   ...              thiago@roihack.com.br    14051-330   14051-330
# 8   ...     autoconhecimento.ana@gmail.com      7113090   07113-090
# 9   ...   leonardoleoreissouza05@gmail.com    08490-600   08490-600
# 10  ...         maria.santiellas@gmail.com    07043-000   07043-000
# 11  ...                and.oliv5@gmail.com    05661-050   05661-050
# 12  ...         giovannamilena50@gmail.com      5756420   05756-420
# 13  ...  sthefanysantossoaresp36@gmail.com    05664-010   05664-010
# 14  ...           lauramilena992@gmail.com      5756420   05756-420
# 15  ...            thaizacarvalh@gmail.com      3064000   03064-000
# 16  ...         esther.farias272@gmail.com      7190050   07190-050
# 17  ...      Cristhian.ruescas83@gmail.com      3641000   03641-000
# 18  ...              Uarasales09@gmail.com      4209001   04209-001
# 19  ...            felipe.1577@outlook.com    07244-420   07244-420
# 20  ...                lucas@ecomilhas.app      5425000   05425-000
# 21  ...      murillo.bnunes@outlook.com.br    07080-120   07080-120
# 22  ...              enzomgalvao@gmail.com      3589001   03589-001
# 23  ...           jairomendes@terra.com.br      1543010   01543-010
# 24  ...   alvesflorenciocaroline@gmail.com      3911010   03911-010
# 25  ...         rafaelgustavo271@gmail.com      3911010   03911-010
# 26  ...               brualm99@hotmail.com    07097-429   07097-429
# 27  ...           leticiasilva41@yahoo.com    07176-090   07176-090
# 28  ...        miguelitovieira68@gmail.com    07124-300   07124-300
# 29  ...           san.zegarrundo@gmail.com    07160-170   07160-170
# 30  ...     guilhermepereira0207@gmail.com      3930100   03930-100
# 31  ...                 bellujrb@gmail.com     11440170   11440-170
# 32  ...                aykelopes@gmail.com      9134620   09134-620
# 33  ...               edu24horas@gmail.com    07121-310   07121-310
# 34  ...              chetoni2022@gmail.com    07240-030   07240-030
# 35  ...               daianenntp@gmail.com      7113040   07113-040
# 36  ...    kurosaki.strawberry17@gmail.com      4331020   04331-020
# 37  ...    kurosaki.strawberry17@gmail.com  23207189822   23207-189
# 38  ...            luara.m.ramos@gmail.com    06327-340   06327-340
# 39  ...        monicainesmartins@gmail.com    12350-000   12350-000
# 40  ...            danielxrios@outlook.com      7132163   07132-163
# 41  ...          luiza.melrufino@gmail.com      7093090   07093-090
# 42  ...       julia.petracontato@gmail.com      3823110   03823-110
# 43  ...    manuela.gadelho@fatec.sp.gov.br    07130-510   07130-510
# 44  ...   thiago.oliveira.caldas@gmail.com    11346-180   11346-180
# 45  ...            ana.b.mamprin@gmail.com      7042220   07042-220
# 46  ...         Luiscassiano3706@gmail.com      7182060   07182-060
# 47  ...            ana.b.mamprin@gmail.com      7042220   07042-220
# 48  ...                 gianemayumi@usp.br      7133070   07133-070
# 49  ...            flavia.firmino@live.com    08280-430   08280-430
# 50  ...        JEFFERSON.AC.LIMA@GMAIL.COM      2310010   02310-010
# 51  ...            thaizacarvalh@gmail.com    03064-000   03064-000
# 52  ...               rgscomunik@gmail.com      5881130   05881-130
# 53  ...    sabrinalopessoares305@gmail.com      7084100   07084-100
# 54  ...               331jhordan@gmail.com      7084100   07084-100
# 55  ...            roberto3511@hotmail.com      7145000   07145-000
# 56  ...            Milenna_231@hotmail.com      3572020   03572-020
#
#                                           bairro          cidade cidadeId  \
# 0                                       Jd Nélia       SÃO PAULO        2
# 1                                 Vila Progresso       GUARULHOS        1
# 2                                      Aclimação       SÃO PAULO        2
# 3                            Jardim Santa Emília       GUARULHOS        1
# 4                          Vila Sítio dos Morros       GUARULHOS        1
# 5                                Parque Uirapuru       GUARULHOS        1
# 6                                    Vila Amélia  RIBEIRÃO PRETO        3
# 7                                    Sumarezinho  RIBEIRÃO PRETO        3
# 8                                         Macedo       GUARULHOS        1
# 9                              Cidade Tiradentes       SÃO PAULO        2
# 10                            Vila das bandeiras       GUARULHOS        1
# 11                                  Paraisópolis       SÃO PAULO        2
# 12                                       Morumbi       SÃO PAULO        2
# 13                                  Paraisópolis       SÃO PAULO        2
# 14                                       Morumbi       SÃO PAULO        2
# 15                                       Tatuapé       SÃO PAULO        2
# 16                                  Parque Cecap       GUARULHOS        1
# 17                                         Penha       SÃO PAULO        2
# 18                                      Ipiranga       SÃO PAULO        2
# 19                                      Pimentas       GUARULHOS        1
# 20                                     Pinheiros       SÃO PAULO        2
# 21                                       Picanço       GUARULHOS        1
# 22  Conjunto Habitacional Padre José de Anchieta       SÃO PAULO        2
# 23                                       Cambuci       SÃO PAULO        2
# 24                                     Vila Rica       SÃO PAULO        2
# 25                                     Vila Rica       SÃO PAULO        2
# 26                       Jardim Flor da Montanha       GUARULHOS        1
# 27                          Vila Nova Bonsucesso       GUARULHOS        1
# 28                                   Vila bremen       GUARULHOS        1
# 29                         Jardim Santo Expedito       GUARULHOS        1
# 30                          Jardim São Cristóvão       SÃO PAULO        2
# 31                                       Enseada         GUARUJA        5
# 32                     recreio da borda do campo     SANTO ANDRE        4
# 33                                Jardim Toscana       GUARULHOS        1
# 34                                Jardim Cumbica       GUARULHOS        1
# 35                                        Macedo       GUARULHOS        1
# 36                                Vila Campestre       SÃO PAULO        2
# 37                                Vila Campestre       SÃO PAULO        2
# 38                                       Cohab 2     CARAPICUÍBA        7
# 39                                     Boa Vista         IGARATÁ        6
# 40                                 Jardim Jovaia       GUARULHOS        1
# 41                            Vila Santo Antônio       GUARULHOS        1
# 42                              Vila Nova Teresa       SÃO PAULO        2
# 43                                        Cocaia       GUARULHOS        1
# 44                                      Gleba II     SÃO VICENTE        8
# 45                                 Jardim Munhoz       GUARULHOS        1
# 46                                Paes de barros       GUARULHOS        1
# 47                                 Jardim munhoz       GUARULHOS        1
# 48                             Jardim Bela Vista       GUARULHOS        1
# 49                         Cidade Lider Itaquera    SÃO PAULO-SP        2
# 50                                   VILA MAZZEI       SÃO PAULO        2
# 51                                       Tatuapé       SÃO PAULO        2
# 52                                  Jd.São Bento       SÃO PAULO        2
# 53                                 Continental 2       GUARULHOS        1
# 54                                 Continental 2       GUARULHOS        1
# 55                              Parque primavera       GUARULHOS        1
# 56                            Jd santa terezinha       SÃO PAULO        2
#
#    incluiOutro                                             perfil  \
# 0            N                                      Desenvolvedor
# 1            N                                      Desenvolvedor
# 2            N                               Analista de Negócios
# 3            N                                      Universitário
# 4            N                                      Desenvolvedor
# 5            N                Estudante de programação e concurso
# 6            N                      Empreendedor e Designer de UX
# 7            N                               Analista de Negócios
# 8            N                             Meu Primeiro Hackathon
# 9            N                                      Desenvolvedor
# 10           N                               Analista de Negócios
# 11    GRUPO 01                                          estudante
# 12    GRUPO 01                                          estudante
# 13    GRUPO 01                                          estudante
# 14    GRUPO 01                                          estudante
# 15           N                                      Desenvolvedor
# 16           N                                      Universitário
# 17           N                                      Desenvolvedor
# 18           N                                      Universitário
# 19           N                                      Universitário
# 20           N                                     Designer de UX
# 21    GRUPO 02                             Meu Primeiro Hackathon
# 22    GRUPO 02                             Meu Primeiro Hackathon
# 23         Não                                      Desenvolvedor
# 24    GRUPO 03                             Meu Primeiro Hackathon
# 25    GRUPO 03                             Meu Primeiro Hackathon
# 26    GRUPO 04                                      Universitário
# 27    GRUPO 04                                      Universitário
# 28    GRUPO 04                                      Universitário
# 29    GRUPO 04                                      Universitário
# 30           N  Analista de Soluções Remotas - Eu me chamo Gui...
# 31           N                                      Desenvolvedor
# 32           N                                      Universitário
# 33           N                                      Universitário
# 34           N                               Analista de Negócios
# 35           N                               Analista de Negócios
# 36    GRUPO 05                             Meu Primeiro Hackathon
# 37    GRUPO 05                             Meu Primeiro Hackathon
# 38    GRUPO 06                                      Desenvolvedor
# 39    GRUPO 06                                      Desenvolvedor
# 40    GRUPO 07                             Meu Primeiro Hackathon
# 41    GRUPO 07                             Meu Primeiro Hackathon
# 42    GRUPO 07                             Meu Primeiro Hackathon
# 43    GRUPO 07                             Meu Primeiro Hackathon
# 44           N                             Meu Primeiro Hackathon
# 45           N                                      Universitário
# 46    GRUPO 08                             Meu Primeiro Hackathon
# 47    GRUPO 08                             Meu Primeiro Hackathon
# 48           N                                      Universitário
# 49           N                                     Designer de UX
# 50           N  ENGENHEIRO DE COMPUTAÇÃO: Tenho formação em sa...
# 51           N                                      Desenvolvedor
# 52           N  Designer de UX: Trabalho com Design e inovação...
# 53    GRUPO 09                                Analista de Sistema
# 54    GRUPO 09                                Analista de Sistema
# 55           N                                      Desenvolvedor
# 56           N                               Analista de Negócios
#
#                    observacao tamanhoCamisetaId
# 0      Tamanho de Camiseta: M                 2
# 1      Tamanho de Camiseta: G                 3
# 2      Tamanho de Camiseta: M                 2
# 3      Tamanho de Camiseta: M                 2
# 4      Tamanho de Camiseta: G                 3
# 5      Tamanho de Camiseta: G                 3
# 6      Tamanho de Camiseta: G                 3
# 7      Tamanho de Camiseta: M                 2
# 8      Tamanho de Camiseta: M                 2
# 9      Tamanho de Camiseta: M                 2
# 10     Tamanho de Camiseta: P                 1
# 11    Tamanho de Camiseta: GG                 4
# 12   Tamanho de Camiseta 2: G                 3
# 13   Tamanho de Camiseta 3: G                 3
# 14   Tamanho de Camiseta 3: G                 3
# 15     Tamanho de Camiseta: P                 1
# 16     Tamanho de Camiseta: P                 1
# 17     Tamanho de Camiseta: G                 3
# 18     Tamanho de Camiseta: P                 1
# 19     Tamanho de Camiseta: G                 3
# 20     Tamanho de Camiseta: G                 3
# 21     Tamanho de Camiseta: P                 1
# 22   Tamanho de Camiseta 2: M                 2
# 23    Tamanho de Camiseta: GG                 4
# 24    Tamanho de Camiseta: GG                 4
# 25    Tamanho de Camiseta: GG                 4
# 26     Tamanho de Camiseta: M                 2
# 27   Tamanho de Camiseta 2: P                 1
# 28     Tamanho de Camiseta: M                 2
# 29   Tamanho de Camiseta 4: M                 2
# 30     Tamanho de Camiseta: M                 2
# 31     Tamanho de Camiseta: G                 3
# 32     Tamanho de Camiseta: G                 3
# 33    Tamanho de Camiseta: GG                 4
# 34     Tamanho de Camiseta: G                 3
# 35     Tamanho de Camiseta: P                 1
# 36    Tamanho de Camiseta: GG                 4
# 37   Tamanho de Camiseta 2: G                 3
# 38     Tamanho de Camiseta: M                 2
# 39   Tamanho de Camiseta 2: G                 3
# 40     Tamanho de Camiseta: M                 2
# 41   Tamanho de Camiseta 2: P                 1
# 42  Tamanho de Camiseta 3: GG                 4
# 43   Tamanho de Camiseta 4: G                 3
# 44     Tamanho de Camiseta: G                 3
# 45    Tamanho de Camiseta: GG                 4
# 46  Tamanho de Camiseta 2: GG                 4
# 47  Tamanho de Camiseta 2: GG                 4
# 48     Tamanho de Camiseta: P                 1
# 49     Tamanho de Camiseta: G                 3
# 50    Tamanho de Camiseta: GG                 4
# 51     Tamanho de Camiseta: P                 1
# 52     Tamanho de Camiseta: G                 3
# 53     Tamanho de Camiseta: M                 2
# 54    Tamanho de Camiseta: GG                 4
# 55     Tamanho de Camiseta: M                 2
# 56     Tamanho de Camiseta: M                 2
#
# [57 rows x 26 columns]

# %%
X = ins['escolaridade2']
y = ins['idade']

# %% [markdown]
# ### Gráficos

# %%
def grafico1(X, y):
    plt.figure(figsize=(10,8))
    plt.title('Escolaridade por Idade', fontdict={'weight':'bold'})
    plt.scatter(X,y,c='darkblue',marker='o')
    plt.xlabel('Escolaridade', fontdict={'weight':'bold','size':16})
    plt.ylabel('Idade', fontdict={'weight':'bold','size':16})
    plt.xticks(rotation=60)
    plt.show()
    
    
def grafico2(X, y, nomeArquivo):
    plt.figure(figsize=(12,8))
    plt.title('Escolaridade por Idade', fontdict={'weight':'bold'})
    plt.bar(X, y, width=1, color='darkblue', edgecolor="white", linewidth=1)
    plt.xlabel('Escolaridade', fontdict={'weight':'bold','size':16})
    plt.ylabel('Idade', fontdict={'weight':'bold','size':16})
    plt.xticks(rotation=60)
    plt.savefig(nomeArquivo, dpi=300)
    plt.show()
    
grafico2(X, y, './Imagens/fig1.jpg')

# %%
# Monta um gráfico de Pizza, com contagem de valores.
def dataPieGraph(dfColuna) -> list: 
    etiquetas=[]; valores=[]
    
    for descricao in dfColuna:
        p=0; localizado=False
        for et in etiquetas:
            if (descricao==et):
                valores[p]+=1
                localizado=True
                break
            else:
                p+=1
        if (not localizado):
            etiquetas.append(descricao)
            valores.append(1)
    
    return [etiquetas, valores]

def dataComputeByRange(faixa, valores) -> list:
    # Array de retorno.
    ret=[]; etiquetas=[]
    for fx in range(len(faixa)):
        ret.append(0)
    #print(ret)

    for etq in faixa:
        if (len(etq)>1):
            etiquetas.append('De {min} à {max}.'.format(min=etq['min'], max=etq['max']))
        else:
            etiquetas.append('{acima}+'.format(acima=etq['acima']))

    for valor in valores:
        for posicao, fx in enumerate(faixa):
            if (len(fx)==1):
                acimaDe=fx['acima']
                if (valor >= acimaDe):
                    ret[posicao]+=1
                    #print('Posição: {}, Valor: {}, Faixa: {}'.format(posicao, valor, fx))
            else:
                min=fx['min']; max=fx['max']
                if (valor >= min and valor <= max):
                    ret[posicao]+=1
                    #print('Posição: {}, Valor: {}, Faixa: {}'.format(posicao, valor, fx))
    return [etiquetas, ret]
    
def pieGraph(dataPie, **kargs) -> None:
    etiquetas=dataPie[0]
    valores=dataPie[1]
    
    # **kargs
    titulo='Titulo'; nomeArquivo='./Imagem'+str.zfill(str(np.random.randint(999)),3)
    colormap='viridis'
        
    for chave in kargs:
        if (str.lower(chave)=='titulo'):
            titulo=kargs['titulo']
        if (str.lower(chave)=='nomearquivo'):
            nomeArquivo=kargs[chave]
        if (str.lower(chave)=='colormap'):
            colormap=kargs[chave]
   
    # https://matplotlib.org/stable/users/explain/colors/colormaps.html
    colors = plt.get_cmap(colormap)(np.linspace(0.2, 0.7, len(etiquetas)))
    
    # plotar...
    fig, ax = plt.subplots(figsize=(12,10))
    plt.title(titulo, fontdict={'weight':'bold'})
    ax.pie(valores, 
           colors=colors,
           radius=3, 
           center=(4, 4),
           textprops={'size':12, 'weight':'bold'},
           wedgeprops={"linewidth": 3, "edgecolor": "white"}, 
           frame=True,
           labels=etiquetas,
           autopct='%1.1f%%',
          )

    #ax.legend(labels=etiquetas,
    #          title=titulo,
    #          loc='upper right',
    #          bbox_to_anchor=(.5, 1, 1, 0)
    #         )

    ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
           ylim=(0, 8), yticks=np.arange(1, 8))
    plt.savefig(nomeArquivo, dpi=300)
    plt.show()

# %%
#
pieGraph(dataPieGraph(ins['genero'])
        ,titulo='Gênero'
        ,nomeArquivo='./Imagens/Genero.jpg'
        ,colorMap='autumn'
        )

pieGraph(dataPieGraph(ins['escolaridade2'])
        ,titulo='Escolaridade'
        ,nomeArquivo='./Imagens/Escolaridade.jpg'
        ,colorMap='coolwarm'
        )

pieGraph(dataPieGraph(ins['cidade'])
        ,titulo='Cidade'
        ,nomeArquivo='./Imagens/Cidade.jpg'
        ,colorMap='Set1'
        )

pieGraph(dataPieGraph(ins['observacao'])
        ,titulo='Observação'
        ,nomeArquivo='./Imagens/Observacao.jpg'
        ,colorMap='cividis'
        )

# %%
dataPie=dataComputeByRange([{'min':0,'max':19},{'min':20,'max':29},{'min':30,'max':39},
                         {'min':40,'max':49},{'min':50,'max':59},{'acima':60}],
                        ins['idade'] 
                   )
pieGraph(dataPie
        ,titulo='Por idade'
        ,nomeArquivo='./Imagens/PorIdade.jpg'
        ,colorMap='BuPu')

# %%
# https://stackoverflow.com/questions/50807744/apply-css-class-to-pandas-dataframe-using-to-html
def geraHTML(dataFrame, arquivoHTML = 'index.html', 
             cssStyle = 'style.css', titulo = 'Html'):
    html_string = '''
        <!DOCTYPE html>
        <html lang='pt-br'>
          <head>
              <title>{titulo}</title>
          </head>
          <link rel="stylesheet" type="text/css" href="{css}"/>
          <body>
                {tabela}
          </body>
        </html>
    '''
    with open(arquivoHTML, 'w') as arquivo:
        arquivo.write(html_string.format(titulo=titulo,
                               tabela=dataFrame.to_html(
                                       index=False,
                                       justify='center',
                                       classes='mystyle'),
                               css=cssStyle
                              ))
    
insHtml=ins[['nroInscricao','nome','cpfAjustado','dataNascAjustada','idade','genero','escolaridade2','instituicao',
             'telefoneAjustado','cepAjustado','cidade','observacao']]       
insHtml.columns=[['Nro. Inscricao','Nome','CPF','Data Nascimento','Idade','Gênero','Escolaridade',
                  'Instituição','Telefone/Cel','CEP','Cidade','Observação']]  
        
geraHTML(insHtml, 
         './html/Hackathon 2024 - Inscrições.html','../css/df_style.css',
         'Hackathon 2024 - Inscrições')

# %%
#### End

# %%
def verificaEmail(email):
    #pattern='([\w+.]){5,30}([@]){1}([.com])'
    pattern='(^[a-zA-Z0-9_.+-]{5,50})+(@)([a-zA-Z0-9-]+)\.([a-zA-Z0-9-.]+$)'
    m=re.search(pattern, email)
    print(m)
    #print(email.group(0))
    if (not m):
        print('nao corresponde')
    else:
        print(m.group(5), m.start(), m.end())
    return m

# %%
#for e in ins['email']:
#    print(e)
#    print(verificaEmail(e))
#    print('----')
    
print(verificaEmail('ola11@hotmail.com'))
# Out:
# <re.Match object; span=(0, 17), match='ola11@hotmail.com'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [318], in <cell line: 6>()
#       1 #for e in ins['email']:
#       2 #    print(e)
#       3 #    print(verificaEmail(e))
#       4 #    print('----')
# ----> 6 print(verificaEmail('ola11@hotmail.com'))
#
# Input In [317], in verificaEmail(email)
#       8     print('nao corresponde')
#       9 else:
# ---> 10     print(m.group(5), m.start(), m.end())
#      11 return m
#
# IndexError: no such group

# %%
import re
p = re.search('\w+[\@]\w+[\.]w+','f@uol.com')
print(p)
# Out:
# None
